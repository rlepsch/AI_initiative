# %%
import pandas as pd

arq = pd.read_csv('arquivos/intelegis-base-buscador-draft.csv')

# %%
arq.head()
# Out:
#    ID                                              TEXTO  \
# 0   1  Processo Civil | Jurisprudência | Busca Jusbra...
# 1   2  NCPC, Processo Civil | Jurisprudência | Busca ...
# 2   3  PROCESSO CIVIL CONEXAO | Jurisprudência | Busc...
# 3   4  Consultas de Jurisprudência - e-SAJ\nesaj.tjsp...
# 4   5  Como Consultar Processos - Tribunal de Justiça...
#
#                                                 LINK  ATR1  ATR2  ATR3  ATR4  \
# 0  https://www.jusbrasil.com.br/jurisprudencia/bu...     2     2     1     3
# 1  https://www.jusbrasil.com.br/jurisprudencia/bu...     2     0     3     1
# 2  https://www.jusbrasil.com.br/jurisprudencia/bu...     2     1     0     2
# 3     esaj.tjsp.jus.br/esaj/portal.do?servico=780000     1     2     1     1
# 4                          www.tjsp.jus.br/Processos     1     0     3     3
#
#    ATR5  ATR6  ATR7  ...    ATR11  ATR12  ATR13  ATR14  ATR15  ATR16  ATR17  \
# 0     3     1     1  ...        0      1      1      0      1      3      0
# ...
